# %%
def exercise1():
    fin = open('words.txt')
    mydict = dict()
    counter = 0
    for line in fin:
        word = line.strip()
        mydict[word] = counter
        counter += 1
    fin.close()
    return mydict

exercise1()
# Out:
# {'aa': 0,
#  'aah': 1,
#  'aahed': 2,
#  'aahing': 3,
#  'aahs': 4,
#  'aal': 5,
#  'aalii': 6,
#  'aaliis': 7,
#  'aals': 8,
#  'aardvark': 9,
#  'aardvarks': 10,
#  'aardwolf': 11,
#  'aardwolves': 12,
#  'aas': 13,
#  'aasvogel': 14,
#  'aasvogels': 15,
#  'aba': 16,
#  'abaca': 17,
#  'abacas': 18,
#  'abaci': 19,
#  'aback': 20,
#  'abacus': 21,
#  'abacuses': 22,
#  'abaft': 23,
#  'abaka': 24,
#  'abakas': 25,
#  'abalone': 26,
#  'abalones': 27,
#  'abamp': 28,
#  'abampere': 29,
#  'abamperes': 30,
#  'abamps': 31,
#  'abandon': 32,
#  'abandoned': 33,
#  'abandoning': 34,
#  'abandonment': 35,
#  'abandonments': 36,
#  'abandons': 37,
#  'abas': 38,
#  'abase': 39,
#  'abased': 40,
#  'abasedly': 41,
#  'abasement': 42,
#  'abasements': 43,
#  'abaser': 44,
#  'abasers': 45,
#  'abases': 46,
#  'abash': 47,
#  'abashed': 48,
#  'abashes': 49,
#  'abashing': 50,
#  'abasing': 51,
#  'abatable': 52,
#  'abate': 53,
#  'abated': 54,
#  'abatement': 55,
#  'abatements': 56,
# ...

# %%
fin = open('words.txt')
englishdict = dict()


def create_diction():
    counter = 0
    dictionairy = dict()
    for line in fin:
        word = line.strip()
        dictionairy[word] = counter
        counter += 1
    return dictionairy
